# %% [markdown]
# # Example 5 - Using xcube to access CUSTOM datasets and experimental zarr
#
# This notebook shows how to access different data sets through the Sentinel Hub API:
#
#
# 1. Access to a **custom data set** ingested into Sentinel Hub via [**BYOD**](https://www.sentinel-hub.com/bring-your-own-data) mechanism
# 2. Access to a **experimental zarr**  ingested into Sentinel Hub.
#
#
# To run this Notebook, make sure the SENTINEL Hub / xcube Integration is setup correctly, see [Ex0-DCFS-Setup](./Ex0-DCFS-Setup.ipynb).

# %%
from xcube_sh.config import CubeConfig
from xcube_sh.cube import open_cube
from xcube_sh.sentinelhub import SentinelHub
import xarray as xr
import numpy as np

# %% [markdown]
# ## Bring your own data

# %% [markdown]
# #### Define bounding box in Mercator coordinates

# %%
x1 = 1545577  # meters
y1 = 5761986  # meters
x2 = 1705367  # meters
y2 = 5857046  # meters

bbox = x1, y1, x2, y2

# %%
width = 512
spatial_res = (x2 - x1) / width
height = max(1, round((y2 - y1) / spatial_res))

# %% [markdown]
# #### Custom data set contains bands RED, GREEN, and BLUE.

# %%
cube_config = CubeConfig(dataset_name='CUSTOM',
                         band_names=['RED', 'GREEN', 'BLUE'],                        
                         tile_size=[width, height],
                         crs='http://www.opengis.net/def/crs/EPSG/0/3857',
                         bbox=bbox,
                         time_range=['2018-01-01', '2019-01-01'],
                         #time_period='7d',
                         spatial_res=spatial_res,
                         band_sample_types='UINT8',
                         collection_id='1a3ab057-3c51-447c-9f85-27d4b633b3f5')
# Out:
# /home/alicja/miniconda3/envs/xcube/lib/python3.9/site-packages/pandas/core/tools/timedeltas.py:132: FutureWarning: Units 'M', 'Y' and 'y' do not represent unambiguous timedelta values and will be removed in a future version
#   return _coerce_scalar_to_timedelta_type(arg, unit=unit, errors=errors)

# %%
cube = open_cube(cube_config)
cube
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_35149/3351353902.py in <module>
# ----> 1 cube = open_cube(cube_config)
#       2 cube
#
# ~/Desktop/projects/xcube-sh/xcube_sh/cube.py in open_cube(cube_config, observer, trace_store_calls, max_cache_size, sentinel_hub, **sh_kwargs)
#      54     elif sh_kwargs:
#      55         raise ValueError(f'unexpected keyword-arguments: {", ".join(sh_kwargs.keys())}')
# ---> 56     cube_store = SentinelHubChunkStore(sentinel_hub, cube_config, observer=observer,
#      57                                        trace_store_calls=trace_store_calls)
#      58     if max_cache_size:
#
# ~/Desktop/projects/xcube-sh/xcube_sh/chunkstore.py in __init__(self, sentinel_hub, cube_config, observer, trace_store_calls)
#     473             d['band_names'] = sentinel_hub.band_names(cube_config.dataset_name)
#     474             cube_config = CubeConfig.from_dict(d)
# --> 475         super().__init__(cube_config,
#     476                          observer=observer,
#     477                          trace_store_calls=trace_store_calls)
#
# ~/Desktop/projects/xcube-sh/xcube_sh/chunkstore.py in __init__(self, cube_config, observer, trace_store_calls)
#      70
#      71         if not self._time_ranges:
# ---> 72             raise ValueError('Could not determine any valid time stamps')
#      73
#      74         width, height = self._cube_config.size
#
# ValueError: Could not determine any valid time stamps

# %%
cubew = cube.isel(time=26)

# %%
rgb_data = np.zeros((305, 512, 3), 'uint8')
rgb_data[:, :, 0] = cubew.RED.values
rgb_data[:, :, 1] = cubew.GREEN.values
rgb_data[:, :, 2] = cubew.BLUE.values

rgb_array = xr.DataArray(rgb_data, dims=('y', 'x', 'b'), coords=dict(x=cube.RED.x, y=cube.RED.y))
rgb_array.plot.imshow(rgb='b', figsize=(16, 10))

# %%
rgb_array
# Out:
# <xarray.DataArray (y: 305, x: 512, b: 3)>
# array([[[ 48,  95,  18],
#         [ 50, 109,  77],
#         [234, 160,   9],
#         ...,
#         [  8,  74,   7],
#         [  5,  73,   7],
#         [  5,  73,   7]],
#
#        [[ 80,  98,   8],
#         [ 37,  89,  23],
#         [ 51,  98,  44],
#         ...,
#         [ 53,  91,   6],
#         [  5,  73,   7],
#         [  5,  73,   7]],
#
#        [[ 20,  77,   7],
#         [  5,  73,   7],
#         [  5,  73,   7],
#         ...,
# ...
#         ...,
#         [193, 195,  43],
#         [251, 157,   3],
#         [254, 165,   0]],
#
#        [[254, 165,   0],
#         [251, 168,   0],
#         [229, 185,  16],
#         ...,
#         [222, 174,  25],
#         [245, 174,   5],
#         [224, 197,  18]],
#
#        [[249, 154,   6],
#         [238, 106,  25],
#         [227,  63,  44],
#         ...,
#         [194, 216,  33],
#         [242, 178,   7],
#         [235, 185,  11]]], dtype=uint8)
# Coordinates:
#   * x        (x) float64 1.546e+06 1.546e+06 1.546e+06 ... 1.705e+06 1.705e+06
#   * y        (y) float64 5.857e+06 5.857e+06 5.856e+06 ... 5.762e+06 5.762e+06
# Dimensions without coordinates: b

# %% [markdown]
# ### Requesting a cube from experimental zarr via Sentinel Hub

# %% [markdown]
# Currently only available via the stage sentinel hub - caution: it might be unstable

# %%
SH = SentinelHub()
SH.api_url = ("https://stage.sentinel-hub.com")

# %%
cube_config_sh_zarr = CubeConfig(
    band_names=['rtoa_4', 'chl_c2rcc'],
    bbox=(12.0, 44.0, 13.33, 46.67),
    spatial_res=0.0028,
    time_range=('2019-05-14', '2019-07-31'),
    collection_id='zarr-0d1b230f-e711-4217-a988-9768a3c91508',
    time_period=None)

# %%
cube = open_cube(cube_config_sh_zarr, sentinel_hub=SH)
cube
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/Desktop/projects/xcube-sh/xcube_sh/sentinelhub.py in maybe_raise_for_response(cls, response)
#     461         try:
# --> 462             response.raise_for_status()
#     463         except requests.HTTPError as e:
#
# ~/miniconda3/envs/xcube/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 500 Server Error: Server Error for url: https://stage.sentinel-hub.com/api/v1/catalog/search
#
# The above exception was the direct cause of the following exception:
#
# SentinelHubError                          Traceback (most recent call last)
# /tmp/ipykernel_35149/733791869.py in <module>
# ----> 1 cube = open_cube(cube_config_sh_zarr, sentinel_hub=SH)
#       2 cube
#
# ~/Desktop/projects/xcube-sh/xcube_sh/cube.py in open_cube(cube_config, observer, trace_store_calls, max_cache_size, sentinel_hub, **sh_kwargs)
#      54     elif sh_kwargs:
#      55         raise ValueError(f'unexpected keyword-arguments: {", ".join(sh_kwargs.keys())}')
# ---> 56     cube_store = SentinelHubChunkStore(sentinel_hub, cube_config, observer=observer,
#      57                                        trace_store_calls=trace_store_calls)
#      58     if max_cache_size:
#
# ~/Desktop/projects/xcube-sh/xcube_sh/chunkstore.py in __init__(self, sentinel_hub, cube_config, observer, trace_store_calls)
#     473             d['band_names'] = sentinel_hub.band_names(cube_config.dataset_name)
#     474             cube_config = CubeConfig.from_dict(d)
# --> 475         super().__init__(cube_config,
#     476                          observer=observer,
#     477                          trace_store_calls=trace_store_calls)
#
# ~/Desktop/projects/xcube-sh/xcube_sh/chunkstore.py in __init__(self, cube_config, observer, trace_store_calls)
#      67         self._observers = [observer] if observer is not None else []
#      68         self._trace_store_calls = trace_store_calls
# ---> 69         self._time_ranges = self.get_time_ranges()
#      70
#      71         if not self._time_ranges:
#
# ~/Desktop/projects/xcube-sh/xcube_sh/chunkstore.py in get_time_ranges(self)
#     495                                  f" {self._cube_config.dataset_name!r}")
#     496         datetime_format = "%Y-%m-%dT%H:%M:%SZ"
# --> 497         features = self._sentinel_hub.get_features(
#     498             collection_name=collection_name,
#     499             bbox=self._cube_config.bbox,
#
# ~/Desktop/projects/xcube-sh/xcube_sh/sentinelhub.py in get_features(self, collection_name, bbox, crs, time_range)
#     204                                          headers=self._get_request_headers('application/json'))
#     205
# --> 206             SentinelHubError.maybe_raise_for_response(response)
#     207
#     208             feature_collection = json.loads(response.content)
#
# ~/Desktop/projects/xcube-sh/xcube_sh/sentinelhub.py in maybe_raise_for_response(cls, response)
#     470             except Exception:
#     471                 pass
# --> 472             raise SentinelHubError(f'{e}: {detail}' if detail else f'{e}', response=response) from e
#     473
#     474
#
# SentinelHubError: 500 Server Error: Server Error for url: https://stage.sentinel-hub.com/api/v1/catalog/search
